# %%
from sklearn.datasets import make_regression
import pandas as pd 
import numpy as np

# %%
df = pd.DataFrame(X)
df.columns = ['x']
df['y'] = y
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df = pd.DataFrame(X)
#       2 df.columns = ['x']
#       3 df['y'] = y
#
# NameError: name 'X' is not defined

# %%
df['x'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
y_mean = np.array([y.mean()] * 100)
y.mean()
# Out:
# 0.1344193000112442

# %%
from sklearn.linear_model import LinearRegression

# Inicializmos el modelo
model_1 = LinearRegression()
model_2 = LinearRegression()
model_3 = LinearRegression()

# Entrenamos el modelo
model_1.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model_1.predict(X)

# %%
import matplotlib.pyplot as plt

X, y = make_regression(n_features=1, noise=30, random_state=0)

# Selector
plt.figure(figsize=(10, 4))

# Data
plt.scatter(X, y, label = 'Random Data', c = 'black')

# Simple model mean
plt.plot(X, y_mean, label = 'Mean', c = 'red')

# Linear Regression
plt.plot(X, y_pred, label = 'Linear Regression', c = 'blue')


# Show
plt.xlabel('Features (x)')
plt.ylabel('Target (y)')
plt.title('Scatter sample plot')
plt.legend()
plt.savefig('../reports/figures/random1.svg')

# %% [markdown]
# # Activity
#
# - Dataset: Boston Housing
# - X: Top-1 correlate feature with target
# - Target: MEDV
# - Model: Linear Regression

# %%
path=('../data/raw/BostonHousing.csv')
df = pd.read_csv(path)
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df['medv'].mean()
# Out:
# 22.532806324110677
